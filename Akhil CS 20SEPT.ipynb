# %%
"
import numpy as np 
import pandas as pd   
labels=['a','b','c','d']  
data=[10,20,30,40]  
arr=np.array(data)  
d={'a':10,'b':20,'c':30,'d':40}  
data=[23,45,67,34,89,90]
#creating series with list 
pd.Series(data)  
#creatinf series with list and index values 
pd.Series(data, index=labels) #or 
pd.Series(data,labels)  
#creating series in  line filling data and index values  
data=pd.Series([23,34,45,56], ['a','b','c','d'])  
#creating list with an array 
pd.Series(arr) #or 
pd.Series(arr, labels)  
#creating dictionary using zip() 
my_dict=dict(zip(data,labels))  
#creating list with dictionary 
pd.Series(d)  
ser1 = pd.Series([1,2,3,4],index = ['USA','India','Italy', 'China'])                                   
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','India', 'China'])    
#accessing values using indexing and index names                                  
ser1['Italy']
ser1[0:3] 
ser1[3] 
ser1 + ser2    
from numpy.random import randn 
randn(5,4) 
#creating dataframe using random with index values and column names 
df = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns=['W', 'X', 'Y', 'Z']) 
#checking for type od dataframe and series in it 
type(df) 
type(df['W'])  
#applying conditional slicing on dataframe 
df>0 
df[df>0]#dataframe where values are greater than 0 
df[df['W']>0]#dataframe where values in column 'W' are greater than 0 
df[df['W']>0]['Y']#column y of dataframe where values in column 'W' are greater than 0 
df[df['W']>0][['Y','X']]#column X and y of dataframe where values in column 'W' are greater than 0 
df[(df['W']>0) & (df['Y'] > 1)]# For two conditions you can use | and & with parenthesis: 
""" More Index Details# # Let's discuss some more features of indexing, 
including resetting the index or setting it something else. We'll also talk about index hierarchy! """
#reset index values back to 0 1 2.... 
df.reset_index() 
#adding a new column in data frame 
newind = ['P','O','W','Y'] 
df['St'] = newind 
#setting a column values as index 
df.set_index('St')  
df.set_index('St',inplace=True) 


df.hist()

# %%
import numpy as np 
import pandas as pd   
labels=['a','b','c','d']  
data=[10,20,30,40]  
arr=np.array(data)  
d={'a':10,'b':20,'c':30,'d':40}  
data=[23,45,67,34,89,90]

# %%
#creating series with list 
pd.Series(data)
# Out:
# 0    23
# 1    45
# 2    67
# 3    34
# 4    89
# 5    90
# dtype: int64

# %%
#creatinf series with list and index values 
labels=['a','b','c','d','e','f']  
pd.Series(data,index=labels) #or 
pd.Series(data,labels)
# Out:
# a    23.0
# b    34.0
# c    45.0
# d    56.0
# e     NaN
# f     NaN
# dtype: float64

# %%
#creating series in  line filling data and index values  
data=pd.Series([23,34,45,56], ['a','b','c','d']) 
data
# Out:
# a    23
# b    34
# c    45
# d    56
# dtype: int64

# %%
#creating list with an array 
pd.Series(arr) #or 
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
#creating list with dictionary 
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA','India','Italy', 'China'])                                   
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','India', 'China']) 
#accessing values using indexing and index names                                  
ser1['Italy']
ser1[0:3] 
ser1[3] 
ser1 + ser2
# Out:
# China      8.0
# Germany    NaN
# India      7.0
# Italy      NaN
# USA        2.0
# dtype: float64

# %%
from numpy.random import randn 
randn(5,4)
# Out:
# array([[-1.20890196, -0.81254867, -0.98622076, -0.56580295],
#        [-0.48953257,  0.85502068, -1.03730879,  0.28052976],
#        [-1.03856716,  0.45638232, -0.33172346, -0.74773452],
#        [-0.78595202,  2.53642763,  1.03331319,  0.20407717],
#        [-0.36684739,  0.67759181,  1.40320182,  1.56280624]])

# %%
#creating dataframe using random with index values and column names 
df = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns=['W', 'X', 'Y', 'Z']) 
df
# Out:
#           W         X         Y         Z
# A  0.610471  0.452780  1.848075  0.438111
# B  1.311725  0.067039  0.055224 -1.500151
# C  1.126024  1.373609 -0.673653  0.296007
# D  2.055211  0.461906  0.791169 -0.462236
# E -1.430983  0.847729 -0.171317  0.736662

# %%
#checking for type od dataframe and series in it 
type(df) 
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
#applying conditional slicing on dataframe 
df>0 
df[df>0]#dataframe where values are greater than 0 
df[df['W']>0]#dataframe where values in column 'W' are greater than 0 
df[df['W']>0]['Y']#column y of dataframe where values in column 'W' are greater than 0 
df[df['W']>0][['Y','X']]#column X and y of dataframe where values in column 'W' are greater than 0 
df[(df['W']>0) & (df['Y'] > 1)]# For two conditions you can use | and & with parenthesis:
# Out:
#           W        X         Y         Z
# A  0.610471  0.45278  1.848075  0.438111

# %%
#reset index values back to 0 1 2.... 
df.reset_index()#reset index values back to 0 1 2.... 
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.610471  0.452780  1.848075  0.438111
# 1     B  1.311725  0.067039  0.055224 -1.500151
# 2     C  1.126024  1.373609 -0.673653  0.296007
# 3     D  2.055211  0.461906  0.791169 -0.462236
# 4     E -1.430983  0.847729 -0.171317  0.736662

# %%
#adding a new column in data frame 
newind = ['P','O','W','Y','S'] 
df['St'] = newind 
df
# Out:
#           W         X         Y         Z St
# A  0.610471  0.452780  1.848075  0.438111  P
# B  1.311725  0.067039  0.055224 -1.500151  O
# C  1.126024  1.373609 -0.673653  0.296007  W
# D  2.055211  0.461906  0.791169 -0.462236  Y
# E -1.430983  0.847729 -0.171317  0.736662  S

# %%
newind = ['P','O','W','Y','S'] 
df['St'] = newind 
#setting a column values as index 
df.set_index('St')
df.set_index('St',inplace=True)   

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f00a5752310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f00a56a9850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f00a5660e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f00a5622550>]],
#       dtype=object)

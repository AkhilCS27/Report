# %% [markdown]
# #Welcome to practice lab 2 - 2nd September 2021
# STRINGS - Strings are bits of text.
# In this practice lab you will learn various string functions (in-build).
# You are supposed to do as instructed below
# REMEMBER  Strings are always written in double quotes
# In python multiple line comments are mentioned with THREE quotes """

# %% [markdown]
# Look at the code segments:-
# ```
# print("We'll be working on strings today")
# print('We'll be working on strings today')
# ```
# Run these segments and analyse the output in the next CODE LINE.
# Reason in the text lines next to the code lines why has this happened?

# %%
print("We'll be working on strings today")
# Out:
# We'll be working on strings today

# %%
print('we'll be working on strings today')
# Out:
#   File "<ipython-input-3-e786ef54c4f5>", line 1
#     print('we'll be working on strings today')
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# Why is the output like this?
# reason here..beacause of single apostrope before and after we it takes it as a single word...........................................(double click to edit)

# %% [markdown]
# O I forgot!
# How would I know you?
# Can you write a code segment to fetch the name of the user? in this case your name.

# %%
input("Enter your name")
# Out:
# Enter your nameAkhil
# 'Akhil'

# %% [markdown]
# Can you also verify whether the entered name is containing only alphabets? Incase user has entered name with numbers in it, please prompt a message back to the user to enter correct name.

# %%
"Akhil".isalpha()
# Out:
# True

# %% [markdown]
# Like above, we can also verify if a given string contains a particulat pattern. Do you know how?..... using this function : - **str.contains('pattern', case=False)**. Lets practice it! prompt user to enter his/her email ID. Verify the entered string if it **contains** ***@*** in it !

# %%
#write code snippet to get email id of the user and then to verify it
mystring=input("Enter your email id")
mystring.contain("@",case=False)
# Out:
# Enter your email id123@gmail.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-85d1418627f3> in <module>()
#       1 #write code snippet to get email id of the user and then to verify it
#       2 mystring=input("Enter your email id")
# ----> 3 mystring.contain("@",case=False)
#
# AttributeError: 'str' object has no attribute 'contain'

# %%
myString=input("Enter your Email ID")
if "@" in myString:
  print("Verified")
else:
  print("Not verified")
# Out:
# Enter your Email ID27akhil2001@gmail.com
# Verified

# %% [markdown]
# Well Done!!
# YOu can also replace old string with a new one... make use of the following function. it's pretty easy to understand.. **str.replace(old_substring, new_substring)** Try it yourself

# %%
#Try using str.replace(old_substring, new_substring) here...
string="It is cloudy"
print(string.replace("cloudy","hot"))
# Out:
# It is hot

# %% [markdown]
# Great!
# You already know that **len()** with return the length of the string. What will happen, if we try to get minimum and maximum value out of a string????
# Create a string **s** and use **min(s)** and **max(s)** on it.

# %%
#Try  using min(), max()
s="wonderful"
print(min(s))
print(max(s))
# Out:
# d
# w

# %% [markdown]
# Try to execute the below code segment:-
# ```
# s1 = "Hello world!"
# print(s1.startswith("Hello"))
# print(s1.endswith("abrakadabra"))
# ```
# Analyse and write in the text box the purpose the functions **string.startswith()** and **string.endswith()**

# %%
#run the above code segment and analyze...
s1="Hello world!"
print(s1.startswith("Hello"))
print(s1.endswith("abrakadabra"))
# Out:
# True
# False

# %% [markdown]
# What have you understood about string.startswith() and string.endswith()? double click here to write your answer..
# For the given sentence it checks whether its starts with the given string or whether it ends with the given string

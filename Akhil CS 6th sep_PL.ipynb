# %%
def fun1():
  l="Dictionary functions list-comprehension and dictionary-comprehension".split(" ")
  d={}
  for i in range(len(l)):
    if l[i]!='and':
      Topics={i+1: l[i]}
      d.update(Topics)
    else:
      continue
    print("Topic {0} for this practice lab is {1}".format(i+1, l[i]))
  return ("summarized as {0}".format(d))

# %%
#call the above function and see the outcome
class function:
    def fun1(self):
        l="Dictionary functions list-comprehension and dictionary-comprehension".split(" ")
        d={}
        for i in range(len(l)):
            if l[i]!='and':
                Topics={i+1: l[i]}
                d.update(Topics)
            else:
                continue
            print("Topic {0} for this practice lab is {1}".format(i+1, l[i]))
        return ("summarized as {0}".format(d))

obj=function()
obj.fun1()
# Out:
# Topic 1 for this practice lab is Dictionary
# Topic 2 for this practice lab is functions
# Topic 3 for this practice lab is list-comprehension
# Topic 5 for this practice lab is dictionary-comprehension
# "summarized as {1: 'Dictionary', 2: 'functions', 3: 'list-comprehension', 5: 'dictionary-comprehension'}"

# %% [markdown]
# Can you give an example of following?:
#
# ```
# .split()
# .update()
# .format()
# continue
# ```
#
#
# Create a function in which you will be using all the above methods/statements

# %%
#create the function using above methods/statement
Method=int(input("Enter 1 for split\nEnter 2 for update\nEnter 3 for format\nEnter 4 for cotinue\n"))
def fun(Method):
  if Method==1:
    string=input('Enter the string')
    string.split()
    return print(string.split())
  elif Method==2:
    marks = {'Social':55, 'Maths':67}
    internal_marks = {'Practical':38}

    marks.update(internal_marks)
    return print(marks)
  elif Method==3:
    s1 = "Its only {price} rupees!"
    a=s1.format(price=50)
    return print(a)
  else:
    for i in range(9):
      if i == 3:
        continue
      print(i)
fun(Method)
# Out:
# Enter 1 for split
# Enter 2 for update
# Enter 3 for format
# Enter 4 for cotinue
# 3
# Its only 50 rupees!

# %% [markdown]
# Analyse the code segment , you may run it too and see what is the difference between method 1 and 2 of using .get() function
#
# ```
# emp = {'name': 'Aman', 'age': 30}
# print('Employee Name: ', emp.get('name'))
# print('Employee Age: ', emp.get('age'))
# # using get - method 1
# print('Employee Salary: ', emp.get('salary'))
# # using get - method 2
# print('Employee Salary: ', emp.get('salary', 0.0))
# ```

# %%
#execute the above code and analyse the difference between method 1 and 2
emp = {'name': 'Aman', 'age': 30}
print('Employee Name: ', emp.get('name'))
print('Employee Age: ', emp.get('age'))
# using get - method 1
print('Employee Salary: ', emp.get('salary'))
# using get - method 2
print('Employee Salary: ', emp.get('salary', 0.0))
# Out:
# Employee Name:  Aman
# Employee Age:  30
# Employee Salary:  None
# Employee Salary:  0.0

# %% [markdown]
# Differentiate between emp.get('salary') and emp.get('salary', 0.0)
#
#
# ANSWER:-----
# get('salary') checks for the key in dictionary since its not found by
# default it prints None
# get('salary',0.0) does the same and prints 0.0 since its defined.

# %% [markdown]
# Have you worked on enumerate function?
# Lets see how it works...
# Python enumerate() function takes any iterable as argument and returns enumerate object using which the iterable can be traversed.
#
# It contains **index and corresponding item** in the iterable object like list, tuple or string.
#
#
# run the below code ... you will see that each item in string 's' is assigned an index by enumerate function

# %%
s='hello'
for i,j in enumerate(s):
  print(i,j)
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o

# %%
#Make use of enumerate() to create a dictionary on days--Mon, Tue, Wed.. 
d={"Mon":"1","tue":"2","wed":"3","thur":"4","fri":"5","sat":"6","sun":"7"}
for i,j in enumerate(d):
    print(i," : ",j)
# Out:
# 0  :  Mon
# 1  :  tue
# 2  :  wed
# 3  :  thur
# 4  :  fri
# 5  :  sat
# 6  :  sun

# %% [markdown]
# convert the below code into a dictionary comprehension
# ```
# s='hello'
# for i,j in enumerate(s):
#   print(i,j)
# ```
#  to get the following output:-
# ```
# {0: 'h', 1: 'e', 2: 'l', 3: 'l', 4: 'o'}
# ```

# %%
#code for dictionary comprehension...
s="hello"
mydict={k:v for (k,v) in enumerate(s)}
print(mydict)
# Out:
# {0: 'h', 1: 'e', 2: 'l', 3: 'l', 4: 'o'}

# %%
"""list comprehension to create a list called filtered_list wherein, it contains the number between 0-50 if

it is x divisible by 2 and if it is x divisible by 5 or not?

If x satisfies both conditions, x is appended to filtered_list."""

# %%
filtered_list=[x for x in range(50) if (x%2==0 and x%5==0) ]
print("filtered_list=",filtered_list)
# Out:
# filtered_list= [0, 10, 20, 30, 40]
